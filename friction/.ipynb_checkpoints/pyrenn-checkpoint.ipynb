# %% [markdown]
# ## PYRENN
# ### Use pyrenn NN to forecast functions

# %% [markdown]
# #### In this example a neural network is used to learn the friction curve of a system, which is given by the following function, where F is the friction force and v is the velocity:

# %% [markdown]
# $F=0.5∗(tanh(25∗v)−tanh(v))+0.2∗tanh(v)+0.03∗v$

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pyrenn as prn
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-080e084a4485> in <module>
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 import pyrenn as prn
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'pyrenn'

# %% [markdown]
# #### Create dataset  P = f(Y) and PTest = f(YTest)

# %%
v=np.arange(-10,10,0.5) ; F= 0.5*(np.tanh(25*v) - np.tanh(v))+0.2*np.tanh(v) + 0.03*v
P=v ;Y=F

v=np.arange(-10,10,0.01) ; F= 0.5*(np.tanh(25*v) - np.tanh(v))+0.2*np.tanh(v) + 0.03*v
PTest=v ; YTest=F

# %%
fig = plt.figure(figsize=(8,4))
ax0 = fig.add_subplot(211)
ax1 = fig.add_subplot(212)

ax0.set_title('Train Data',fontsize=10)

ax0.plot(P,Y, label='Train')
ax0.grid()
ax1.set_title('Test Data',fontsize=10)

ax1.plot(PTest,YTest, label='Test')
ax1.grid()
fig.tight_layout()

# %% [markdown]
# #### Build a NetworkModel

# %%
net = prn.CreateNN([1,3,3,1])

# %% [markdown]
# #### Train the model

# %%
net = prn.train_LM(P,Y,net,verbose=True,k_max=100,E_stop=1e-5)
# Out:
# Iteration:  0 		Error:  9.341056685762013 	scale factor:  3.0
# Iteration:  1 		Error:  4.632588977704877 	scale factor:  0.3
# Iteration:  2 		Error:  2.1280946328988986 	scale factor:  0.3
# Iteration:  3 		Error:  0.6638014950676677 	scale factor:  0.03
# Iteration:  4 		Error:  0.4749695972655585 	scale factor:  0.03
# Iteration:  5 		Error:  0.4374108710381369 	scale factor:  0.03
# Iteration:  6 		Error:  0.40305330564815656 	scale factor:  0.03
# Iteration:  7 		Error:  0.3751349260607615 	scale factor:  0.03
# Iteration:  8 		Error:  0.3734259020707679 	scale factor:  0.003
# Iteration:  9 		Error:  0.2812108409014041 	scale factor:  0.003
# Iteration:  10 		Error:  0.270005774029554 	scale factor:  0.03
# Iteration:  11 		Error:  0.2626175470735571 	scale factor:  0.03
# Iteration:  12 		Error:  0.25474118101301446 	scale factor:  0.03
# Iteration:  13 		Error:  0.2457650468134473 	scale factor:  0.03
# Iteration:  14 		Error:  0.2350289284554782 	scale factor:  0.03
# Iteration:  15 		Error:  0.22196999033689635 	scale factor:  0.03
# Iteration:  16 		Error:  0.20625846898471462 	scale factor:  0.03
# Iteration:  17 		Error:  0.18799906097239547 	scale factor:  0.03
# Iteration:  18 		Error:  0.1681635702111542 	scale factor:  0.03
# Iteration:  19 		Error:  0.15737535810324352 	scale factor:  0.003
# Iteration:  20 		Error:  0.07330733185250637 	scale factor:  0.003
# Iteration:  21 		Error:  0.06474250335558171 	scale factor:  0.00030000000000000003
# Iteration:  22 		Error:  0.0639611392534239 	scale factor:  0.00030000000000000003
# Iteration:  23 		Error:  0.003785983488979796 	scale factor:  0.00030000000000000003
# Iteration:  24 		Error:  0.0009921112092997999 	scale factor:  0.00030000000000000003
# Iteration:  25 		Error:  0.0006783767690433007 	scale factor:  0.00030000000000000003
# Iteration:  26 		Error:  0.00037876902193815875 	scale factor:  0.00030000000000000003
# Iteration:  27 		Error:  0.00023122685505613924 	scale factor:  0.00030000000000000003
# Iteration:  28 		Error:  0.00015253696818845472 	scale factor:  0.00030000000000000003
# Iteration:  29 		Error:  0.0001082499182988984 	scale factor:  0.00030000000000000003
# Iteration:  30 		Error:  8.150631569003516e-05 	scale factor:  0.00030000000000000003
# Iteration:  31 		Error:  6.416231247073023e-05 	scale factor:  0.00030000000000000003
# Iteration:  32 		Error:  5.220380231286938e-05 	scale factor:  0.00030000000000000003
# Iteration:  33 		Error:  4.3546691775484674e-05 	scale factor:  0.00030000000000000003
# Iteration:  34 		Error:  3.7038353413210094e-05 	scale factor:  0.00030000000000000003
# Iteration:  35 		Error:  3.200019023892782e-05 	scale factor:  0.00030000000000000003
# Iteration:  36 		Error:  2.8009515591693047e-05 	scale factor:  0.00030000000000000003
# Iteration:  37 		Error:  2.478996270548458e-05 	scale factor:  0.00030000000000000003
# Iteration:  38 		Error:  2.2153314677129605e-05 	scale factor:  0.00030000000000000003
# Iteration:  39 		Error:  1.996695639669781e-05 	scale factor:  0.00030000000000000003
# Iteration:  40 		Error:  1.813476154615134e-05 	scale factor:  0.00030000000000000003
# Iteration:  41 		Error:  1.6585374900386635e-05 	scale factor:  0.00030000000000000003
# Iteration:  42 		Error:  1.5264751369805965e-05 	scale factor:  0.00030000000000000003
# Iteration:  43 		Error:  1.4131245961970213e-05 	scale factor:  0.00030000000000000003
# Iteration:  44 		Error:  1.3152288300608673e-05 	scale factor:  0.00030000000000000003
# Iteration:  45 		Error:  1.2302073219887729e-05 	scale factor:  0.00030000000000000003
# Iteration:  46 		Error:  1.1559921461340074e-05 	scale factor:  0.00030000000000000003
# Iteration:  47 		Error:  1.0909093411709212e-05 	scale factor:  0.00030000000000000003
# Iteration:  48 		Error:  1.0335915941498176e-05 	scale factor:  0.00030000000000000003
# Iteration:  49 		Error:  9.829129902414888e-06 	scale factor:  0.00030000000000000003
# Termination Error reached

# %% [markdown]
# #### Predict train data

# %%
y = prn.NNOut(P,net)

# %% [markdown]
# #### Predict test data

# %%
ytest = prn.NNOut(PTest,net)

# %% [markdown]
# ### Plot results

# %%
fig = plt.figure(figsize=(10,6))
ax0 = fig.add_subplot(211)
fs=18

#Train Data
ax0.set_title('Train Data',fontsize=fs)
ax0.plot(P,y,color='b',lw=2,label='NN Output')
ax0.plot(P,Y,color='r',marker='None',linestyle=':',lw=3,markersize=8,label='Train Data')
ax0.tick_params(labelsize=fs-2)
ax0.legend(fontsize=fs-2,loc='upper left')
ax0.grid()

ax1 = fig.add_subplot(212)
#Test Data
ax1.set_title('Test Data',fontsize=fs)
ax1.plot(PTest,ytest,color='b',lw=2,label='NN Output')
ax1.plot(PTest,YTest,color='r',marker='None',linestyle=':',lw=3,markersize=8,label='Test Data')
ax1.tick_params(labelsize=fs-2)
ax1.legend(fontsize=fs-2,loc='upper left')
ax1.grid()

fig.tight_layout()
plt.show()

# %% [markdown]
# ### In this example a neural network is used to learn the response Y to an input P of a second order transfer function described by:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def generate_aprbs(nstep):
    # random signal generation
    a = np.random.randint(-5, 5, nstep)  # range for amplitude
    b = np.random.randint(10, 100, nstep) # range for freuency
    b[0] = 0

    for i in range(1,np.size(b)):
        b[i] = b[i-1]+b[i]

    # Random Signal
    i=0
    random_signal = np.zeros(nstep)
    while b[i]<np.size(random_signal):
        k = b[i]
        random_signal[k:] = a[i]
        i=i+1

    # PRBS
    a = np.zeros(nstep)
    j = 0
    while j < nstep:
        a[j] = 5
        a[j+1] = -5
        j = j+2

    i=0
    prbs = np.zeros(nstep)
    while b[i]<np.size(prbs):
        k = b[i]
        prbs[k:] = a[i]
        i=i+1

        return random_signal

# %%
P = generate_aprbs(2000)
plt.figure(0) 
plt.subplot(2,1,1)
plt.plot(P, label='Random Signal')
plt.legend()
plt.show()

# %%
Ptest = generate_aprbs(2000)
plt.figure(0) 
plt.subplot(2,1,1)
plt.plot(Ptest, label='Random Signal')
plt.legend()
plt.show()

# %%
s = P
Y = 10/ (0.1*(s**2)+s+100)
s = Ptest
Ytest = 10/ (0.1*(s**2)+s+100)
plt.figure(0) 
plt.subplot(2,1,1)
plt.plot(Y, label='Random Signal')
plt.legend()
plt.show()

# %%
## dIn = [0]  delays input
## dIntern=[1] delay of 1 timestep in the hidden layers
## dOut=[1,2] delay of 1 and 2 timesteps from the output to the first layer 

net = prn.CreateNN([1,2,2,1],dIn=[0],dIntern=[1],dOut=[1,2,3])

# %%
net = prn.train_LM(P,Y,net,verbose=True,k_max=100,E_stop=1e-3)
# Out:
# Iteration:  0 		Error:  81.00806948645402 	scale factor:  3.0
# Iteration:  1 		Error:  0.2267932576851866 	scale factor:  0.3
# Iteration:  2 		Error:  0.0009175831518351546 	scale factor:  0.03
# Termination Error reached

# %%
y = prn.NNOut(P,net)
ytest = prn.NNOut(Ptest,net)

# %%
fig = plt.figure(figsize=(11,7))
ax0 = fig.add_subplot(211)
ax1 = fig.add_subplot(212)
fs=18

#Train Data
ax0.set_title('Train Data',fontsize=fs)
ax0.plot(y,color='b',lw=2,label='NN Output')
ax0.plot(Y,color='r',marker='None',linestyle=':',lw=3,markersize=8,label='Train Data')
ax0.tick_params(labelsize=fs-2)
ax0.legend(fontsize=fs-2,loc='upper left')
ax0.grid()

#Test Data
ax1.set_title('Test Data',fontsize=fs)
ax1.plot(ytest,color='b',lw=2,label='NN Output')
ax1.plot(Ytest,color='r',marker='None',linestyle=':',lw=3,markersize=8,label='Test Data')
ax1.tick_params(labelsize=fs-2)
ax1.legend(fontsize=fs-2,loc='upper left')
ax1.grid()

fig.tight_layout()
plt.show()
