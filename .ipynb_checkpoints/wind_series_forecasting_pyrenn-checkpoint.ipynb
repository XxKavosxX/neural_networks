# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.preprocessing import normalize, MinMaxScaler
from sklearn.model_selection import train_test_split
import pyrenn as prn

# %% [markdown]
# ### Import datasets

# %%
april = pd.read_excel("database/wind_series/april_92.xls", header=None, names=['A'])
april = pd.DataFrame(april)
may = pd.read_excel("database/wind_series/may_92.xls", header=None, names=['M'])
may = pd.DataFrame(may)

# %% [markdown]
# ### Define Lags

# %%
lag = [1, 2, 3, 4, 5, 25, 200]

# %% [markdown]
# ### Build the train lagged matrix of inputs

# %% [markdown]
# ### Build test and validation lagged matrix

# %%
lag_april = april.iloc[200:4320].reset_index(drop=True)
lag_may_val = may.iloc[200:2500].reset_index(drop=True)
lag_may_tst = may.iloc[2501:4460].reset_index(drop=True)

#lag matrix
for i in lag:
    lag_april = pd.concat([lag_april, april.iloc[200-i:4320-i].reset_index(drop=True)], axis=1)                          
    lag_may_val = pd.concat([lag_may_val, may.iloc[200-i:2500-i].reset_index(drop=True)], axis=1)
    lag_may_tst = pd.concat([lag_may_tst, may.iloc[2501-i:4460-i].reset_index(drop=True)], axis=1)

lag_april.columns=['A','A-1','A-2','A-3','A-4','A-5','A-25','A-200'] 
lag_may_val.columns=['A','A-1','A-2','A-3','A-4','A-5','A-25','A-200']
lag_may_tst.columns=['A','A-1','A-2','A-3','A-4','A-5','A-25','A-200']

#dataset
X_train = lag_april
X_val = lag_may_val
X_test = lag_may_tst

Y_train = april.iloc[200:4320]
Y_val = may.iloc[200:2500]
Y_test = may.iloc[2501:4460]

# %% [markdown]
# ### Verify correlationship of the matrix

# %%
corr_coef = np.corrcoef(lag_april, lag_april)[0][:7]
corr_coef
# Out:
# array([1.        , 0.96374947, 0.89844131, 0.90279273, 0.91375579,
#        0.8582129 , 0.88860148])

# %% [markdown]
# #### Normalize Datasets

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.fit_transform(X_val)
X_test = scaler.fit_transform(X_test)

Y_train = scaler.fit_transform(Y_train).flatten()
Y_val = scaler.fit_transform(Y_val).flatten()
Y_test = scaler.fit_transform(Y_test).flatten()

# %% [markdown]
# ### Building Network

# %%
nn  = prn.CreateNN([8,100,1])

# %% [markdown]
# #### Train

# %%
a = X_train.T

# %%
regr = prn.train_LM(a, Y_train, nn ,verbose=True, k_max=100,E_stop=1e-3)
# Out:
# Iteration:  0 		Error:  626.6558403727198 	scale factor:  3.0
# Iteration:  1 		Error:  2.0674375093677204 	scale factor:  0.3
# Iteration:  2 		Error:  0.024565249097606365 	scale factor:  0.03
# Iteration:  3 		Error:  0.006180704765014358 	scale factor:  0.003
# Iteration:  4 		Error:  0.0032418269948538588 	scale factor:  0.003
# Iteration:  5 		Error:  0.0023278303429349937 	scale factor:  0.003
# Iteration:  6 		Error:  0.0016244443551247435 	scale factor:  0.003
# Iteration:  7 		Error:  0.0012383736667647225 	scale factor:  0.003
# Iteration:  8 		Error:  0.001013678669135232 	scale factor:  0.003
# Iteration:  9 		Error:  0.0008686177375251535 	scale factor:  0.003
# Termination Error reached

# %% [markdown]
# ##### Predict test data

# %%
pred = prn.NNOut(X_test.T,nn)

# %%
fig = plt.figure(figsize=(15,4))
plt.plot(np.arange(1959),Y_test.flatten(), 'b',label='Real')
plt.plot(np.arange(1959),pred.flatten(), color='r',linestyle=':',lw=3, markersize=5,label='Predicted')
plt.legend()
plt.ylabel("Wind Speed")
plt.xlabel("Data Sample")
# Out:
# Text(0.5, 0, 'Data Sample')

# %% [markdown]
# ##### Predict validation data

# %%
pred_val = prn.NNOut(X_val.T,nn)

# %%
fig = plt.figure(figsize=(15,4))
plt.plot(np.arange(2300),Y_val.flatten(), 'b',label='Real')
plt.plot(np.arange(2300),pred_val.flatten(), color='g',linestyle=':',lw=3, markersize=5,label='Predicted')
plt.legend()
plt.ylabel("Wind Speed")
plt.xlabel("Data Sample")
# Out:
# Text(0.5, 0, 'Data Sample')
